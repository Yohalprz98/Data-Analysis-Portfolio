# %%
from bs4 import BeautifulSoup
import requests
import smtplib #to send emails
import time
import datetime

URL = 'https://world-weather.info/forecast/colombia/medellin/'
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

page = requests.get(URL, headers=headers)

soup1 = BeautifulSoup(page.content, "html.parser")

soup2 = BeautifulSoup(soup1.prettify(), 'html.parser')


#The data collected is specified
temp = soup2.find(id="weather-now-number").get_text()
real_feel = soup2.find("dd").get_text()
hr = soup2.find("p").get_text()

temp = temp.strip()[:3]
real_feel = real_feel.strip()[:3]
hr = hr.strip()[25:30]

#The date when the data was collected will be saved
import datetime
today = datetime.date.today()

#Creating CSV to store data
import csv
header = ['Temp','Real Feel', 'Date', 'Hour']
data = [temp, real_feel, today, hr]

#running this more than once would delete all the data because recreates the csv
"""with open('WorldWeatherWebScraperDataset.csv', 'w', newline='', encoding='UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(header)
    writer.writerow(data)
 """ 
import pandas as pd
df = pd.read_csv(r'C:\Users\yohal\WorldWeatherWebScraperDataset.csv')

def check_weather():
    URL = 'https://world-weather.info/forecast/colombia/medellin/'
    headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

    page = requests.get(URL, headers=headers)

    soup1 = BeautifulSoup(page.content, "html.parser")

    soup2 = BeautifulSoup(soup1.prettify(), 'html.parser')


    #The data collected is specified
    temp = soup2.find(id="weather-now-number").get_text()
    real_feel = soup2.find("dd").get_text()
    hr = soup2.find("p").get_text()

    temp = temp.strip()[:3]
    real_feel = real_feel.strip()[:3]
    hr = hr.strip()[25:30]

    #The date when the data was collected will be saved
    import datetime
    today = datetime.date.today()
    
    #Creating CSV to store data
    import csv
    header = ['Temp','Real Feel', 'Date', 'Hour']
    data = [temp, real_feel, today, hr]

    #running this more than once would delete all the data because recreates the csv
    with open('WorldWeatherWebScraperDataset.csv', 'a+', newline='', encoding='UTF8') as f:
        writer = csv.writer(f)
        writer.writerow(data)
      
    
check_weather()
import pandas as pd
df = pd.read_csv(r'WorldWeatherWebScraperDataset.csv')
print(df)


# this is a timer that would run method "check_price" saving to the csv the product with its price and the date when the data 
# was taken.
# It's set to run every 86400(24hrs)
#while(True):
#    check_price()
#    time.sleep(86400)
# Out:
#    Temp  Real Feel        Date   Hour
# 0    68         70  2023-12-29  23:49
# 1    68         70  2023-12-29  23:54
# 2    68         70  2023-12-29  23:57
# 3    68         68  2023-12-30  00:01
# 4    68         68  2023-12-30  00:06
# 5    68         68  2023-12-30  00:13
